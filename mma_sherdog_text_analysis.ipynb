# %%
import pandas as pd
import numpy as np
import nltk
import re
import string

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from textblob import TextBlob
from wordcloud import WordCloud

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("mma_data_sherdog.csv")

df.head()
# Out:
#                            Organization                      Event  \
# 0  Ultimate Fighting Championship (UFC)  UFC 219 - Cyborg vs. Holm
# 1  Ultimate Fighting Championship (UFC)  UFC 219 - Cyborg vs. Holm
# 2  Ultimate Fighting Championship (UFC)  UFC 219 - Cyborg vs. Holm
# 3  Ultimate Fighting Championship (UFC)  UFC 219 - Cyborg vs. Holm
# 4  Ultimate Fighting Championship (UFC)  UFC 219 - Cyborg vs. Holm
#
#          Date  Fight Number Result                Fighter  \
# 0  2017-12-30             0    win  Cris "Cyborg" Justino
# 1  2017-12-30             0   loss             Holly Holm
# 2  2017-12-30             1    win    Khabib Nurmagomedov
# 3  2017-12-30             1   loss          Edson Barboza
# 4  2017-12-30             2    win             Dan Hooker
#
#                Opponent                         Method  Round  Time  \
# 0            Holly Holm           Decision (Unanimous)    5.0  5:00
# 1     Cristiane Justino           Decision (Unanimous)    5.0  5:00
# 2        Edson Barboza            Decision (Unanimous)    3.0  5:00
# 3  Khabib Nurmagomedov            Decision (Unanimous)    3.0  5:00
# 4        Marc Diakiese   Submission (Guillotine Choke)    3.0  0:42
#
#                                                  Url
# 0  http://www.sherdog.com/events/UFC-219-Cyborg-v...
# 1  http://www.sherdog.com/events/UFC-219-Cyborg-v...
# 2  http://www.sherdog.com/events/UFC-219-Cyborg-v...
# 3  http://www.sherdog.com/events/UFC-219-Cyborg-v...
# 4  http://www.sherdog.com/events/UFC-219-Cyborg-v...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8958 entries, 0 to 8957
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Organization  8958 non-null   str
#  1   Event         8958 non-null   str
#  2   Date          8958 non-null   str
#  3   Fight Number  8958 non-null   int64
#  4   Result        8958 non-null   str
#  5   Fighter       8958 non-null   str
#  6   Opponent      8958 non-null   str
#  7   Method        8958 non-null   str
#  8   Round         8958 non-null   float64
#  9   Time          8956 non-null   str
#  10  Url           8958 non-null   str
# dtypes: float64(1), int64(1), str(9)
# memory usage: 2.4 MB

# %%
print(df.columns)
# Out:
# Index(['Organization', 'Event', 'Date', 'Fight Number', 'Result', 'Fighter',
#        'Opponent', 'Method', 'Round', 'Time', 'Url'],
#       dtype='str')

# %%
df.columns = df.columns.str.strip()
print(df.columns)
# Out:
# Index(['Organization', 'Event', 'Date', 'Fight Number', 'Result', 'Fighter',
#        'Opponent', 'Method', 'Round', 'Time', 'Url'],
#       dtype='str')

# %%
print(df.columns.tolist())
# Out:
# ['Organization', 'Event', 'Date', 'Fight Number', 'Result', 'Fighter', 'Opponent', 'Method', 'Round', 'Time', 'Url']

# %%
print(df.columns)
# Out:
# Index(['Organization', 'Event', 'Date', 'Fight Number', 'Result', 'Fighter',
#        'Opponent', 'Method', 'Round', 'Time', 'Url'],
#       dtype='str')

# %%
df.head()
# Out:
#                            Organization                      Event  \
# 0  Ultimate Fighting Championship (UFC)  UFC 219 - Cyborg vs. Holm
# 1  Ultimate Fighting Championship (UFC)  UFC 219 - Cyborg vs. Holm
# 2  Ultimate Fighting Championship (UFC)  UFC 219 - Cyborg vs. Holm
# 3  Ultimate Fighting Championship (UFC)  UFC 219 - Cyborg vs. Holm
# 4  Ultimate Fighting Championship (UFC)  UFC 219 - Cyborg vs. Holm
#
#          Date  Fight Number Result                Fighter  \
# 0  2017-12-30             0    win  Cris "Cyborg" Justino
# 1  2017-12-30             0   loss             Holly Holm
# 2  2017-12-30             1    win    Khabib Nurmagomedov
# 3  2017-12-30             1   loss          Edson Barboza
# 4  2017-12-30             2    win             Dan Hooker
#
#                Opponent                         Method  Round  Time  \
# 0            Holly Holm           Decision (Unanimous)    5.0  5:00
# 1     Cristiane Justino           Decision (Unanimous)    5.0  5:00
# 2        Edson Barboza            Decision (Unanimous)    3.0  5:00
# 3  Khabib Nurmagomedov            Decision (Unanimous)    3.0  5:00
# 4        Marc Diakiese   Submission (Guillotine Choke)    3.0  0:42
#
#                                                  Url
# 0  http://www.sherdog.com/events/UFC-219-Cyborg-v...
# 1  http://www.sherdog.com/events/UFC-219-Cyborg-v...
# 2  http://www.sherdog.com/events/UFC-219-Cyborg-v...
# 3  http://www.sherdog.com/events/UFC-219-Cyborg-v...
# 4  http://www.sherdog.com/events/UFC-219-Cyborg-v...

# %%
df.columns
# Out:
# Index(['Organization', 'Event', 'Date', 'Fight Number', 'Result', 'Fighter',
#        'Opponent', 'Method', 'Round', 'Time', 'Url'],
#       dtype='str')

# %%
print(df.head())
print(df.columns.tolist())
# Out:
#                            Organization                      Event  \
# 0  Ultimate Fighting Championship (UFC)  UFC 219 - Cyborg vs. Holm
# 1  Ultimate Fighting Championship (UFC)  UFC 219 - Cyborg vs. Holm
# 2  Ultimate Fighting Championship (UFC)  UFC 219 - Cyborg vs. Holm
# 3  Ultimate Fighting Championship (UFC)  UFC 219 - Cyborg vs. Holm
# 4  Ultimate Fighting Championship (UFC)  UFC 219 - Cyborg vs. Holm
#
#          Date  Fight Number Result                Fighter  \
# 0  2017-12-30             0    win  Cris "Cyborg" Justino
# 1  2017-12-30             0   loss             Holly Holm
# 2  2017-12-30             1    win    Khabib Nurmagomedov
# 3  2017-12-30             1   loss          Edson Barboza
# 4  2017-12-30             2    win             Dan Hooker
#
#                Opponent                         Method  Round  Time  \
# 0            Holly Holm           Decision (Unanimous)    5.0  5:00
# 1     Cristiane Justino           Decision (Unanimous)    5.0  5:00
# 2        Edson Barboza            Decision (Unanimous)    3.0  5:00
# 3  Khabib Nurmagomedov            Decision (Unanimous)    3.0  5:00
# 4        Marc Diakiese   Submission (Guillotine Choke)    3.0  0:42
#
#                                                  Url
# 0  http://www.sherdog.com/events/UFC-219-Cyborg-v...
# 1  http://www.sherdog.com/events/UFC-219-Cyborg-v...
# 2  http://www.sherdog.com/events/UFC-219-Cyborg-v...
# 3  http://www.sherdog.com/events/UFC-219-Cyborg-v...
# 4  http://www.sherdog.com/events/UFC-219-Cyborg-v...
# ['Organization', 'Event', 'Date', 'Fight Number', 'Result', 'Fighter', 'Opponent', 'Method', 'Round', 'Time', 'Url']

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns)
df.head()
# Out:
# Index(['Organization', 'Event', 'Date', 'Fight Number', 'Result', 'Fighter',
#        'Opponent', 'Method', 'Round', 'Time', 'Url'],
#       dtype='str')
#                            Organization                      Event  \
# 0  Ultimate Fighting Championship (UFC)  UFC 219 - Cyborg vs. Holm
# 1  Ultimate Fighting Championship (UFC)  UFC 219 - Cyborg vs. Holm
# 2  Ultimate Fighting Championship (UFC)  UFC 219 - Cyborg vs. Holm
# 3  Ultimate Fighting Championship (UFC)  UFC 219 - Cyborg vs. Holm
# 4  Ultimate Fighting Championship (UFC)  UFC 219 - Cyborg vs. Holm
#
#          Date  Fight Number Result                Fighter  \
# 0  2017-12-30             0    win  Cris "Cyborg" Justino
# 1  2017-12-30             0   loss             Holly Holm
# 2  2017-12-30             1    win    Khabib Nurmagomedov
# 3  2017-12-30             1   loss          Edson Barboza
# 4  2017-12-30             2    win             Dan Hooker
#
#                Opponent                         Method  Round  Time  \
# 0            Holly Holm           Decision (Unanimous)    5.0  5:00
# 1     Cristiane Justino           Decision (Unanimous)    5.0  5:00
# 2        Edson Barboza            Decision (Unanimous)    3.0  5:00
# 3  Khabib Nurmagomedov            Decision (Unanimous)    3.0  5:00
# 4        Marc Diakiese   Submission (Guillotine Choke)    3.0  0:42
#
#                                                  Url
# 0  http://www.sherdog.com/events/UFC-219-Cyborg-v...
# 1  http://www.sherdog.com/events/UFC-219-Cyborg-v...
# 2  http://www.sherdog.com/events/UFC-219-Cyborg-v...
# 3  http://www.sherdog.com/events/UFC-219-Cyborg-v...
# 4  http://www.sherdog.com/events/UFC-219-Cyborg-v...

# %%
df.to_csv("mma_data_sherdog_nlp_processed.csv", index=False)
